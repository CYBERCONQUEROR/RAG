# %%
! pip install langchain_core langchain_community pypdf pymupdf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---------------------------------------- 2.5/2.5 MB 15.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 13.9 MB/s  0:00:00
# ...
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 13.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/18.4 MB ? eta -:--:--
#    ----- ---------------------------------- 2.6/18.4 MB 13.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 5.5/18.4 MB 13.5 MB/s eta 0:00:01
# ...

# %%
from langchain_core.documents import Document

# %%
doc = Document(page_content="This is the content of the document.", metadata={"source": "example.pdf"})
